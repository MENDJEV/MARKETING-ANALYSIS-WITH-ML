# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import  dendrogram, linkage

# %%
df = pd.read_csv(r'C:\Users\DELL\Documents\POLYTECH_DIJON\outils-IA\ProjetIA\Marketing_Analysis\MARKETING-ANALYSIS-WITH-ML\data\processed\pca_marketing_campaign.csv')
